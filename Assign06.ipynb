# %% [markdown]
# <a href="https://colab.research.google.com/github/maeyda-masroor/assign06/blob/days/Assign06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assign 01 : . Using self
# Assignment:
# Create a class Student with attributes name and marks. Use the self keyword to initialize these values via a constructor. Add a method display() that prints student details.

# %%
class Student:
  def __init__(self,name,marks):
    self.name=name
    self.marks=marks
  def display(self):
    print(self.name,self.marks)

studemt = Student("Ram",90)
studemt.display()
# Out:
# Ram 90

# %% [markdown]
# Using cls
# Assignment:
# Create a class Counter that keeps track of how many objects have been created. Use a class variable and a class method with cls to manage and display the count.

# %%
class Counter:
  def __init__(self,count):
    self.count = count

  @classmethod
  def displayCount(cls,count):
    cls.count = count
    count=count+1
    print(count)
    #print(cls.count)

if __name__ == "__main__":
  input = [1,2,3,4,5]
  n = len(input)
  for _ in range(n):
    Counter.displayCount(3)
# Out:
# 4
# 4
# 4
# 4
# 4

# %% [markdown]
#  Public Variables and Methods
# Assignment:
# Create a class Car with a public variable brand and a public method start(). Instantiate the class and access both from outside the class.

# %%
class Car:
  brand = "Toyota"
  def start():
    print("Car started")

Car.start()
print(Car.brand)
# Out:
# Car started
# Toyota

# %% [markdown]
# Class Variables and Class Methods
# Assignment:
# Create a class Bank with a class variable bank_name. Add a class method change_bank_name(cls, name) that allows changing the bank name. Show that it affects all instances.

# %%
class Bank:
  bank_name = "SBI"
  def __init__(self,bank_name):
    self.bank_name = bank_name
  @classmethod
  def display(cls,bank_name):
    bank_name = cls.bank_name
    print(bank_name)

bank = Bank("SBI")
bank.display("c")
# Out:
# SBI

# %% [markdown]
# Create a class MathUtils with a static method add(a, b) that returns the sum. No class or instance variables should be used.

# %%
class MathUtils:
  @staticmethod
  def add(a,b):
    return a + b
print(MathUtils.add(2,3))
# Out:
# 5

# %% [markdown]
#  Constructors and Destructors
# Assignment:
# Create a class Logger that prints a message when an object is created (constructor) and another message when it is destroyed (destructor).

# %%
class Logger:
    def __init__(self):
        print("class created")

    def __del__(self):
        print("delete class")

logger = Logger()  # ✅ Don't pass 'self' when creating an instance
del logger          # ✅ 'del' is used with the variable name, not as a function
# Out:
# class created
# delete class

# %% [markdown]
# Access Modifiers: Public, Private, and Protected
# Assignment:
# Create a class Employee with:
#
# a public variable name,
#
# a protected variable _salary, and
#
# a private variable __ssn.
#
# Try accessing all three variables from an object of the class and document what happens.

# %%
class Empolyee:
  name = "Ali"
  _salary = "20,0000"
  __ssn= "123"
  def __init__(self,name,salary,ssn):
    self.name = name
    self._salary = salary
    self.__ssn = ssn

emp =  Empolyee("Ali",20000,123)
print(emp.name)
print(emp._salary)
print(emp._Empolyee__ssn)
# Out:
# Ali
# 20000
# 123

# %% [markdown]
# The super() Function
# Assignment:
# Create a class Person with a constructor that sets the name. Inherit a class Teacher from it, add a subject field, and use super() to call the base class constructor.

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def display_info(self):
        print(f"Name: {self.name}")

class Teacher(Person):
    def __init__(self, name, subject):
        super().__init__(name)
        self.subject = subject

    def display_info(self):
        super().display_info()
        print(f"Subject: {self.subject}")

# main
person = Person("Ali")
teacher = Teacher("Ali", "Mathematics")

person.display_info()
teacher.display_info()

# Get subject from teacher
print(f"Teacher's subject is: {teacher.subject}")
# Out:
# Name: Ali
# Name: Ali
# Subject: Mathematics
# Teacher's subject is: Mathematics

# %% [markdown]
# Abstract Classes and Methods
# Assignment:
# Use the abc module to create an abstract class Shape with an abstract method area(). Inherit a class Rectangle that implements area().

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

rectangle = Rectangle(5, 3)
print(rectangle.area())
# Out:
# 15

# %% [markdown]
# Instance Methods
# Assignment:
# Create a class Dog with instance variables name and breed. Add an instance method bark() that prints a message including the dog's name.

# %%
class Dog:
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed

    def bark(self):
        print(f"{self.name} is barking!")

dog = Dog("Buddy", 3)
dog.bark()
# Out:
# Buddy is barking!

# %% [markdown]
# Create a class Book with a class variable total_books. Add a class method increment_book_count() to increase the count when a new book is added.

# %%
class Book:
    total_books = 0  # Class variable

    def __init__(self, title):
        self.title = title
        Book.increment_book_count()

    @classmethod
    def increment_book_count(cls):
        cls.total_books += 1

    @classmethod
    def display_total_books(cls):
        print(f"Total books: {cls.total_books}")
# Creating some books
book1 = Book("Python Basics")
book2 = Book("Data Science 101")
book3 = Book("Machine Learning")

# Display total book count
Book.display_total_books()
# Out:
# Total books: 3

# %% [markdown]
# Static Methods
# Assignment:
# Create a class TemperatureConverter with a static method celsius_to_fahrenheit(c) that returns the Fahrenheit value.

# %%
class TemperatureConvertor:
  @staticmethod
  def celsius_to_fahrenheit(celsius):
    fahrenheit = (celsius * 9/5) + 32
    return fahrenheit

print({TemperatureConvertor.celsius_to_fahrenheit(37)})
# Out:
# {98.6}

# %% [markdown]
# Composition
# Assignment:
# Create a class Engine and a class Car. Use composition by passing an Engine object to the Car class during initialization. Access a method of the Engine class via the Car class.

# %%
class Engine:
    def __init__(self, name):
        self.name = name

    def start(self):
        print("Engine started")

class Car:
    def __init__(self, engine):
        self.engine = engine

engine = Engine("V8")
car = Car(engine)
print(car.engine.name)  # Output: V8
# Out:
# V8

# %% [markdown]
# Assignment:
# Create a class Department and a class Employee. Use aggregation by having a Department object store a reference to an Employee object that exists independently of it.

# %%
class Department:
  def __init__(self,name):
    self.name = name
  def display(self):
    print(self.name)
class Employee:
    def __init__(self,name,department):
      self.name = name
      self.department = department
    def display(self):
      print(self.name)
      self.department.display()

department = Department("IT")
employee = Employee("Ali",department)
employee.display()
# Out:
# Ali
# IT

# %% [markdown]
# Method Resolution Order (MRO) and Diamond Inheritance
# Assignment:
# Create four classes:
#
# A with a method show(),
#
# B and C that inherit from A and override show(),
#
# D that inherits from both B and C.
#
# Create an object of D and call show() to observe MRO.

# %%
class A:
  def display(self):
    return "hello from A"

class B(A):
  def display(self):
    return "hello from B"

class C(A):
  def display(self):
    return "hello from C"

class D (B,C):
  pass

d = D()
d.display()
print(D.mro())
# Out:
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]

# %% [markdown]
# Function Decorators
# Assignment:
# Write a decorator function log_function_call that prints "Function is being called" before a function executes. Apply it to a function say_hello().

# %%
class Say_hello():
  def __init__(self,func):
    self.func = func
    self.count = 0
  def __call__(self,*args,**kwargc):
    self.count+=1
    print(f"decoreator call {self.count} or {self.func.__name__}")
    return self.func(*args,**kwargc)

@Say_hello
def say_hello():
  print("hello")

say_hello()
say_hello()
# Out:
# decoreator call 1 or say_hello
# hello
# decoreator call 2 or say_hello
# hello

# %% [markdown]
# Class Decorators
# Assignment:
# Create a class decorator add_greeting that modifies a class to add a greet() method returning "Hello from Decorator!". Apply it to a class Person

# %%
def add_greeting(cls):
    def greeting(self):
        return f"Decorator: hello from {self.__class__.__name__} | {self.name}"
    cls.greeting = greeting  # Correct method name and indentation
    return cls

@add_greeting
class Person:
    def __init__(self, name):
        self.name = name

person = Person("Ali")
print(person.greeting())
# Out:
# Decorator: hello from Person | Ali

# %% [markdown]
# Property Decorators: @property, @setter, and @deleter
# Assignment:
# Create a class Product with a private attribute _price. Use @property to get the price, @price.setter to update it, and @price.deleter to delete it

# %%
class Product:
  def __init__(self,price):
    self._price = price

  @property
  def price(self):
    return self._price

  @price.setter
  def price(self, new_price):
    if not isinstance(new_price, int):
      raise ValueError("price should be int")
      self._price = new_price
    else:
      self._price = new_price

  @price.deleter
  def price(self):
    print("delete price")
    del self._price

product = Product(100)
print(product.price)
product.price = 200
print(product.price)
del product.price
# Out:
# 100
# 200
# delete price

# %% [markdown]
# Assignment:
# Create a class Multiplier with an __init__() to set a factor. Define a __call__() method that multiplies an input by the factor. Test it with callable() and by calling the object like a function.

# %%
class Multiplier:
  def __init__(self,number):
    self.number = number

  def __call__(self,number):
    return self.number * 3

multiplier = Multiplier(2)
print(multiplier(3))
# Out:
# 6

# %% [markdown]
# ssignment:
# Create a custom exception InvalidAgeError. Write a function check_age(age) that raises this exception if age < 18. Handle it with try...except.

# %%
class InvalidAgeError(Exception):
  def __init__(self,age):
    super().__init__(f"invalid age {age}")
    self.age = age
def invalidage(age):
  if age > 18:
    print(f"invalid age {age}")
  else:
    print("valid age")

try:
  invalidage(10)
except InvalidAgeError as e:
  print(e)
# Out:
# valid age

# %% [markdown]
# Assignment:
# Create a class Countdown that takes a start number. Implement __iter__() and __next__() to make the object iterable in a for-loop, counting down to 0.

# %%
class Countdown:
    def __init__(self, start):
        self.current = start

    def __iter__(self):
        return self  # The object itself is the iterator

    def __next__(self):
        if self.current < 0:
            raise StopIteration  # End the iteration
        value = self.current
        self.current -= 1
        return value

# Example usage:
for number in Countdown(5):
    print(number)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0
